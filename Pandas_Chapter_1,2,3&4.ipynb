# %%
pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    -- ------------------------------------- 0.8/11.5 MB 4.0 MB/s eta 0:00:03
#    ------------- -------------------------- 3.9/11.5 MB 9.5 MB/s eta 0:00:01
#    --------------------- ------------------ 6.3/11.5 MB 10.3 MB/s eta 0:00:01
#    ----------------------------- ---------- 8.4/11.5 MB 10.6 MB/s eta 0:00:01
#    ---------------------------------------  11.3/11.5 MB 10.9 MB/s eta 0:00:01
#    ---------------------------------------- 11.5/11.5 MB 9.8 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Reading the data in python

# %% [markdown]
# ## Importing Insurance file

# %% [markdown]
# ## Initial Analysis of the data

# %%
import pandas as pd

# %%
Insurance_df=pd.read_csv("insurance.csv")

# %%
Insurance_df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %% [markdown]
# ## Importing Sales_Transactions-2017

# %%
Sales_Transactions2017_df=pd.read_csv("Sales Transactions-2017.csv")

# %%
Sales_Transactions2017_df
# Out:
#              Date    Voucher               Party            Product  \
# 0        1/4/2017      Sal:1    SOLANKI PLASTICS      DONA-VAI-9100
# 1        1/4/2017      Sal:1    SOLANKI PLASTICS    LITE FOAM(1200)
# 2        1/4/2017      Sal:2  SARNESWARA TRADERS  VISHNU CHOTA WINE
# 3        1/4/2017      Sal:2  SARNESWARA TRADERS    LITE FOAM(1200)
# 4        1/4/2017      Sal:2  SARNESWARA TRADERS      DONA-VAI-9100
# ...           ...        ...                 ...                ...
# 47285  31/03/2018  Sal:10042                 Vkp        10*10 SHEET
# 47286         NaN        NaN                 NaN                NaN
# 47287         NaN        NaN                 NaN                NaN
# 47288         NaN    Total                   NaN                NaN
# 47289         NaN    Total                   NaN                NaN
#
#                 Qty          Rate           Gross        Disc  Voucher Amount
# ...

# %%
df=pd.read_csv("data.tsv.txt",sep="@")   ## It is text file, so we need to add txt after the file name then it is seprated by @ simbol so we need to add that in ()

# %%
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
order_df=pd.read_csv("data.tsv.txt",sep="@",index_col=["order_id"])

# %%
order_df
# Out:
#           quantity                              item_name  \
# order_id
# 1                1           Chips and Fresh Tomato Salsa
# 1                1                                   Izze
# 1                1                       Nantucket Nectar
# 1                1  Chips and Tomatillo-Green Chili Salsa
# 2                2                           Chicken Bowl
# ...            ...                                    ...
# 1833             1                          Steak Burrito
# 1833             1                          Steak Burrito
# 1834             1                     Chicken Salad Bowl
# 1834             1                     Chicken Salad Bowl
# 1834             1                     Chicken Salad Bowl
#
#                                          choice_description item_price
# order_id
# 1                                                       NaN     $2.39
# 1                                              [Clementine]     $3.39
# ...

# %%
df=pd.read_csv("data.tsv.txt",sep="@")

# %%
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
Insurance_df.shape    ## 1338 - observations --- 7 - columns
# Out:
# (1338, 7)

# %%
Insurance_df.head(10)
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520
# 5   31  female  25.740         0     no  southeast   3756.62160
# 6   46  female  33.440         1     no  southeast   8240.58960
# 7   37  female  27.740         3     no  northwest   7281.50560
# 8   37    male  29.830         2     no  northeast   6406.41070
# 9   60  female  25.840         0     no  northwest  28923.13692

# %%
Insurance_df.tail(10)
# Out:
#       age     sex     bmi  children smoker     region      charges
# 1328   23  female  24.225         2     no  northeast  22395.74424
# 1329   52    male  38.600         2     no  southwest  10325.20600
# 1330   57  female  25.740         2     no  southeast  12629.16560
# 1331   23  female  33.400         0     no  southwest  10795.93733
# 1332   52  female  44.700         3     no  southwest  11411.68500
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030

# %%
Incurance_df.dtypes               ## checking the data types
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %%
Incurance_df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
Insurance_df["age"].mean()
# Out:
# np.float64(39.20702541106129)

# %%
Insurance_df.describe(include="all")
# Out:
#                 age   sex          bmi     children smoker     region  \
# count   1338.000000  1338  1338.000000  1338.000000   1338       1338
# unique          NaN     2          NaN          NaN      2          4
# top             NaN  male          NaN          NaN     no  southeast
# freq            NaN   676          NaN          NaN   1064        364
# mean      39.207025   NaN    30.663397     1.094918    NaN        NaN
# std       14.049960   NaN     6.098187     1.205493    NaN        NaN
# min       18.000000   NaN    15.960000     0.000000    NaN        NaN
# 25%       27.000000   NaN    26.296250     0.000000    NaN        NaN
# 50%       39.000000   NaN    30.400000     1.000000    NaN        NaN
# 75%       51.000000   NaN    34.693750     2.000000    NaN        NaN
# max       64.000000   NaN    53.130000     5.000000    NaN        NaN
#
#              charges
# count    1338.000000
# unique           NaN
# top              NaN
# freq             NaN
# ...

# %%
Insurance_df.isna().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
df.isna()
# Out:
#       order_id  quantity  item_name  choice_description  item_price
# 0        False     False      False                True       False
# 1        False     False      False               False       False
# 2        False     False      False               False       False
# 3        False     False      False                True       False
# 4        False     False      False               False       False
# ...        ...       ...        ...                 ...         ...
# 4617     False     False      False               False       False
# 4618     False     False      False               False       False
# 4619     False     False      False               False       False
# 4620     False     False      False               False       False
# 4621     False     False      False               False       False
#
# [4622 rows x 5 columns]

# %%
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
df.isna().sum()   ## finding null values
# Out:
# order_id                 0
# quantity                 0
# item_name                0
# choice_description    1246
# item_price               0
# dtype: int64

# %%
Sales_Transactions2017_df.isna() ## it diplaying true or false(Boolean)
# Out:
#         Date  Voucher  Party  Product    Qty   Rate  Gross   Disc  \
# 0      False    False  False    False  False  False  False   True
# 1      False    False  False    False  False  False  False   True
# 2      False    False  False    False  False  False  False   True
# 3      False    False  False    False  False  False  False   True
# 4      False    False  False    False  False  False  False   True
# ...      ...      ...    ...      ...    ...    ...    ...    ...
# 47285  False    False  False    False  False  False  False   True
# 47286   True     True   True     True   True   True   True   True
# 47287   True     True   True     True   True   True   True   True
# 47288   True    False   True     True  False  False  False  False
# 47289   True    False   True     True  False  False  False  False
#
#        Voucher Amount
# 0               False
# 1                True
# 2               False
# 3                True
# 4                True
# ...               ...
# ...

# %%
Sales_Transactions2017_df.isna().sum()
# Out:
# Date               5388
# Voucher            5375
# Party                15
# Product            5388
# Qty                5375
# Rate               5376
# Gross              5376
# Disc              44432
# Voucher Amount    35942
# dtype: int64

# %%
Incurance_df=pd.read_csv("insurance.csv")

# %%
Incurance_df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
Insurance_df["region"].unique()
# Out:
# array(['southwest', 'southeast', 'northwest', 'northeast'], dtype=object)

# %%
len(Insurance_df["region"].unique())
# Out:
# 4

# %%
Insurance_df["region"].nunique()
# Out:
# 4

# %%
Insurance_df["region"].value_counts()
# Out:
# region
# southeast    364
# southwest    325
# northwest    325
# northeast    324
# Name: count, dtype: int64

# %%
Insurance_df["region"].values
# Out:
# array(['southwest', 'southeast', 'southeast', ..., 'southeast',
#        'southwest', 'northwest'], shape=(1338,), dtype=object)

# %%
order_df
# Out:
#           quantity                              item_name  \
# order_id
# 1                1           Chips and Fresh Tomato Salsa
# 1                1                                   Izze
# 1                1                       Nantucket Nectar
# 1                1  Chips and Tomatillo-Green Chili Salsa
# 2                2                           Chicken Bowl
# ...            ...                                    ...
# 1833             1                          Steak Burrito
# 1833             1                          Steak Burrito
# 1834             1                     Chicken Salad Bowl
# 1834             1                     Chicken Salad Bowl
# 1834             1                     Chicken Salad Bowl
#
#                                          choice_description item_price
# order_id
# 1                                                       NaN     $2.39
# 1                                              [Clementine]     $3.39
# ...

# %%
order_df["item_name"]
# Out:
# order_id
# 1                Chips and Fresh Tomato Salsa
# 1                                        Izze
# 1                            Nantucket Nectar
# 1       Chips and Tomatillo-Green Chili Salsa
# 2                                Chicken Bowl
#                         ...
# 1833                            Steak Burrito
# 1833                            Steak Burrito
# 1834                       Chicken Salad Bowl
# 1834                       Chicken Salad Bowl
# 1834                       Chicken Salad Bowl
# Name: item_name, Length: 4622, dtype: object

# %%
order_df["item_name"].nunique()
# Out:
# 50

# %%
order_df["item_name"].unique()
# Out:
# array(['Chips and Fresh Tomato Salsa', 'Izze', 'Nantucket Nectar',
#        'Chips and Tomatillo-Green Chili Salsa', 'Chicken Bowl',
#        'Side of Chips', 'Steak Burrito', 'Steak Soft Tacos',
#        'Chips and Guacamole', 'Chicken Crispy Tacos',
#        'Chicken Soft Tacos', 'Chicken Burrito', 'Canned Soda',
#        'Barbacoa Burrito', 'Carnitas Burrito', 'Carnitas Bowl',
#        'Bottled Water', 'Chips and Tomatillo Green Chili Salsa',
#        'Barbacoa Bowl', 'Chips', 'Chicken Salad Bowl', 'Steak Bowl',
#        'Barbacoa Soft Tacos', 'Veggie Burrito', 'Veggie Bowl',
#        'Steak Crispy Tacos', 'Chips and Tomatillo Red Chili Salsa',
#        'Barbacoa Crispy Tacos', 'Veggie Salad Bowl',
#        'Chips and Roasted Chili-Corn Salsa',
#        'Chips and Roasted Chili Corn Salsa', 'Carnitas Soft Tacos',
#        'Chicken Salad', 'Canned Soft Drink', 'Steak Salad Bowl',
#        '6 Pack Soft Drink', 'Chips and Tomatillo-Red Chili Salsa', 'Bowl',
# ...

# %%
order_df["item_name"].value_counts()
# Out:
# item_name
# Chicken Bowl                             726
# Chicken Burrito                          553
# Chips and Guacamole                      479
# Steak Burrito                            368
# Canned Soft Drink                        301
# Chips                                    211
# Steak Bowl                               211
# Bottled Water                            162
# Chicken Soft Tacos                       115
# Chips and Fresh Tomato Salsa             110
# Chicken Salad Bowl                       110
# Canned Soda                              104
# Side of Chips                            101
# Veggie Burrito                            95
# Barbacoa Burrito                          91
# Veggie Bowl                               85
# Carnitas Bowl                             68
# Barbacoa Bowl                             66
# Carnitas Burrito                          59
# Steak Soft Tacos                          55
# 6 Pack Soft Drink                         54
# ...

# %% [markdown]
# ## Chapter 2 - filtering and Sorting operations

# %%
football_df=pd.read_csv("Euro_2012_stats_TEAM.csv")

# %%
football_df
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
football_df.head(10)
# Out:
#              Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 0         Croatia      4               13                12             51.9%
# 1  Czech Republic      4               13                18             41.9%
# 2         Denmark      4               10                10             50.0%
# 3         England      5               11                18             50.0%
# 4          France      3               22                24             37.9%
# 5         Germany     10               32                32             47.8%
# 6          Greece      5                8                18             30.7%
# 7           Italy      6               34                45             43.0%
# 8     Netherlands      2               12                36             25.0%
# 9          Poland      2               15                23             39.4%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# ...

# %% [markdown]
# ## Task -------> How to check all the columns in pandas (EX: in the above data cloumns are hidden, so we need to find and complete it)

# %%
football_df.max()
# Out:
# Team                          Ukraine
# Goals                              12
# Shots on target                    42
# Shots off target                   45
# Shooting Accuracy               55.9%
# % Goals-to-shots                 9.3%
# Total shots (inc. Blocked)        110
# Hit Woodwork                        6
# Penalty goals                       1
# Penalties not scored                1
# Headed goals                        3
# Passes                           4317
# Passes completed                 3820
# Passing Accuracy                88.7%
# Touches                          5585
# Crosses                           101
# Dribbles                          106
# Corners Taken                      44
# Tackles                           122
# Clearances                        137
# Interceptions                     136
# Clearances off line               2.0
# Clean Sheets                        5
# Blocks                             29
# Goals conceded                      9
# ...

# %%
football_df.head(35)
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
pd.set_option('display.max_columns', None)      ## this is used to display all the columns in the data sheet

# %%
football_df
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
football_df[football_df["Goals"]>4]
# Out:
#         Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 3    England      5               11                18             50.0%
# 5    Germany     10               32                32             47.8%
# 6     Greece      5                8                18             30.7%
# 7      Italy      6               34                45             43.0%
# 10  Portugal      6               22                42             34.3%
# 12    Russia      5                9                31             22.5%
# 13     Spain     12               42                33             55.9%
# 14    Sweden      5               17                19             47.2%
#
#    % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 3             17.2%                          40             0              0
# 5             15.6%                          80             2              1
# 6             19.2%                          32             1              1
# ...

# %%
football_df[football_df["Shots on target"]>20]
# Out:
#         Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 4     France      3               22                24             37.9%
# 5    Germany     10               32                32             47.8%
# 7      Italy      6               34                45             43.0%
# 10  Portugal      6               22                42             34.3%
# 13     Spain     12               42                33             55.9%
#
#    % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 4              6.5%                          65             1              0
# 5             15.6%                          80             2              1
# 7              7.5%                         110             2              0
# 10             9.3%                          82             6              0
# 13            16.0%                         100             0              1
#
# ...

# %%
football_df[football_df["Shots off target"]>30]  ## for my data frame or date sheet im passing everything in index. name_df[]
# Out:
#            Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5       Germany     10               32                32             47.8%
# 7         Italy      6               34                45             43.0%
# 8   Netherlands      2               12                36             25.0%
# 10     Portugal      6               22                42             34.3%
# 12       Russia      5                9                31             22.5%
# 13        Spain     12               42                33             55.9%
#
#    % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5             15.6%                          80             2              1
# 7              7.5%                         110             2              0
# 8              4.1%                          60             2              0
# 10             9.3%                          82             6              0
# ...

# %%
football_df[football_df["Team"]=="Germany"]
# Out:
#       Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5  Germany     10               32                32             47.8%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5            15.6%                          80             2              1
#
#    Penalties not scored  Headed goals  Passes  Passes completed  \
# 5                     0             2    2774              2427
#
#   Passing Accuracy  Touches  Crosses  Dribbles  Corners Taken  Tackles  \
# 5            87.4%     3761      101        60             35       91
#
#    Clearances  Interceptions  Clearances off line  Clean Sheets  Blocks  \
# 5          73             69                  0.0             1      11
#
#    Goals conceded  Saves made Saves-to-shots ratio  Fouls Won  Fouls Conceded  \
# 5               6          10                62.6%         63              49
#
#    Offsides  Yellow Cards  Red Cards  Subs on  Subs off  Players Used
# ...

# %%
football_df
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
football_df[["Goals","Yellow Cards", "Red Cards"]]
# Out:
#     Goals  Yellow Cards  Red Cards
# 0       4             9          0
# 1       4             7          0
# 2       4             4          0
# 3       5             5          0
# 4       3             6          0
# 5      10             4          0
# 6       5             9          1
# 7       6            16          0
# 8       2             5          0
# 9       2             7          1
# 10      6            12          0
# 11      1             6          1
# 12      5             6          0
# 13     12            11          0
# 14      5             7          0
# 15      2             5          0

# %%
filter_data=football_df[["Team","Goals","Yellow Cards", "Red Cards"]]

# %%
filter_data
# Out:
#                    Team  Goals  Yellow Cards  Red Cards
# 0               Croatia      4             9          0
# 1        Czech Republic      4             7          0
# 2               Denmark      4             4          0
# 3               England      5             5          0
# 4                France      3             6          0
# 5               Germany     10             4          0
# 6                Greece      5             9          1
# 7                 Italy      6            16          0
# 8           Netherlands      2             5          0
# 9                Poland      2             7          1
# 10             Portugal      6            12          0
# 11  Republic of Ireland      1             6          1
# 12               Russia      5             6          0
# 13                Spain     12            11          0
# 14               Sweden      5             7          0
# 15              Ukraine      2             5          0

# %%
filter_data.sort_values(by="Goals",ascending=False)
# Out:
#                    Team  Goals  Yellow Cards  Red Cards
# 13                Spain     12            11          0
# 5               Germany     10             4          0
# 10             Portugal      6            12          0
# 7                 Italy      6            16          0
# 14               Sweden      5             7          0
# 12               Russia      5             6          0
# 3               England      5             5          0
# 6                Greece      5             9          1
# 1        Czech Republic      4             7          0
# 0               Croatia      4             9          0
# 2               Denmark      4             4          0
# 4                France      3             6          0
# 8           Netherlands      2             5          0
# 9                Poland      2             7          1
# 15              Ukraine      2             5          0
# 11  Republic of Ireland      1             6          1

# %%
football_df[football_df["Yellow Cards"]>8]
# Out:
#         Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 0    Croatia      4               13                12             51.9%
# 6     Greece      5                8                18             30.7%
# 7      Italy      6               34                45             43.0%
# 10  Portugal      6               22                42             34.3%
# 13     Spain     12               42                33             55.9%
#
#    % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 0             16.0%                          32             0              0
# 6             19.2%                          32             1              1
# 7              7.5%                         110             2              0
# 10             9.3%                          82             6              0
# 13            16.0%                         100             0              1
#
# ...

# %%
football_df["Yellow Cards"]>8
# Out:
# 0      True
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6      True
# 7      True
# 8     False
# 9     False
# 10     True
# 11    False
# 12    False
# 13     True
# 14    False
# 15    False
# Name: Yellow Cards, dtype: bool

# %%
football_df["Goals"]>4
# Out:
# 0     False
# 1     False
# 2     False
# 3      True
# 4     False
# 5      True
# 6      True
# 7      True
# 8     False
# 9     False
# 10     True
# 11    False
# 12     True
# 13     True
# 14     True
# 15    False
# Name: Goals, dtype: bool

# %%
(football_df["Yellow Cards"]>8) & (football_df["Goals"]>4)
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6      True
# 7      True
# 8     False
# 9     False
# 10     True
# 11    False
# 12    False
# 13     True
# 14    False
# 15    False
# dtype: bool

# %%
football_df[(football_df["Yellow Cards"]>8) & (football_df["Goals"]>4)]
# Out:
#         Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 6     Greece      5                8                18             30.7%
# 7      Italy      6               34                45             43.0%
# 10  Portugal      6               22                42             34.3%
# 13     Spain     12               42                33             55.9%
#
#    % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 6             19.2%                          32             1              1
# 7              7.5%                         110             2              0
# 10             9.3%                          82             6              0
# 13            16.0%                         100             0              1
#
#     Penalties not scored  Headed goals  Passes  Passes completed  \
# 6                      1             0    1187               911
# 7                      0             2    3016              2531
# ...
